# %% [markdown]
# ## <span>Алгоритмы </span>
#
# Здравствуйте, хлопцы!
# Вот ваши алгоритмы)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Поддержите начинающего чеканной монетой :)
#
# 6578 6473 2987
# (карта не существует ;)
# (just joke u know?)
# !!!!Переводить никому не нужно!!!!

# %% [markdown]
# *2)*
#
# ![image.png](attachment:f82d1860-91e9-48e8-acd1-07c26b3ed7aa.png)

# %% [markdown]
# ![image.png](attachment:894b4710-5a94-4bc2-b935-41b771019efa.png)

# %% [markdown]
# *3)*
#
# ![image.png](attachment:aeeef6aa-a97b-43da-82f5-245e7c1dae74.png)

# %% [markdown]
# *4)*
#
# ![image.png](attachment:bfba0af8-ae92-46a1-9578-92149e8106ea.png)
#
# *(Все три способа)*

# %% [markdown]
# ![image.png](attachment:063596cd-b3f1-4f2a-a507-c3679866c30d.png)

# %% [markdown]
# ![image.png](attachment:5deccba3-a0e4-406e-b006-9cb9b602f21e.png)

# %% [markdown]
# ![image.png](attachment:c681c8f5-b175-41bb-a414-9aa3b6177fe6.png)

# %% [markdown]
# *5)*
#
# ![image.png](attachment:820fdf99-14a1-48b9-a782-28b26fd70735.png)

# %%
#Произведение
prod = 1
i = 1

while i <= 10: #для примера возьмем 10
    prod *= i
    i += 1

# %%
#Получение члена последовательности
y = 1
i = 1

while i <= 10:
    y += 1 # 1 2 3 4 5 ...
    i += 1
print(y)

# %% [markdown]
# *6)*
#
# ![image.png](attachment:bf3c95e3-6cfb-4347-b2f1-5f92d2399b85.png)

# %%
#В данном случае just пример,я в вас верю
