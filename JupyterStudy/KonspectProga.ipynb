# %% [markdown]
# Теория

# %% [markdown]
# Вопрос 4(Подпрограмма):

# %% [markdown]
# ![image.png](attachment:4cf0cd3d-7512-4e20-acb9-f4174f48b24e.png)

# %% [markdown]
# ![image.png](attachment:14509346-b388-4c5a-82ec-ca5030485b57.png)

# %% [markdown]
# ![image.png](attachment:5c0b44ba-f95c-4db2-8c1c-59cab7835787.png)

# %% [markdown]
# ![image.png](attachment:da9c8bf5-08dd-4438-a1d9-8bf0240141d2.png)

# %% [markdown]
# ![image.png](attachment:51790936-999f-44be-b718-4e8fb560df58.png)

# %% [markdown]
# Вопрос 5(Функции):
